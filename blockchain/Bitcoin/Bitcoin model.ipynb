# %% [markdown]
# # Bitcoin

# %%
import random
import time

from src import Block, Client, Miner, Transaction

# %%
number_of_clients = 10
number_of_miners = 2
modeling_time = 60

# %%
start_time = time.time()
print(f"Время начала работы модели: {start_time}")


clients = [Client() for _ in range(number_of_clients)]
miners = [Miner() for _ in range(number_of_miners)]
print(f"Создано {number_of_clients} клиентов и {number_of_miners} майнеров. ")



block = Block(nonce="I'm hash of the initial block")
for client in clients:
    t = Transaction("Server", client, 5000)
    block.add_transaction(t)
    
chain = [block]
print("Клиентам сети выданы начальные средства, создан начальный блок в цепи")


unprocessed_transactions = []

print("Запуск модели сети. ")
current_time = 0
while current_time < modeling_time:
    print("Модельное время: ", int(current_time))
    
    sender, recipient = random.sample(clients, 2)
    value = random.randint(10, 50)
    print(f"Клиент {sender.__str__()} прислал {value} денег клиенту {recipient.__str__()}")
    t = Transaction(sender, recipient, value)
    print("Создана транзакция", t)
    print(f"Идентификатор транзакции: {t.id}\n")
    unprocessed_transactions.append(t)
    
    if len(unprocessed_transactions) >= 3:
        miner = random.choice(miners)
        print(f"Майнер {miner.__str__()} обработает текущую цепочку транзакций")
        block = miner.create_block(chain, unprocessed_transactions)
        print("Создан блок", block)
        chain.append(block)
        unprocessed_transactions = []
        
    time.sleep(1 + random.random())
    current_time = time.time() - start_time
    
print("Блоков в цепи:\t", len(chain))
print("Необработанных транзакций:\t", len(unprocessed_transactions))
# Out:
# Время начала работы модели: 1634132674.7524447
# Создано 10 клиентов и 2 майнеров.
# Клиентам сети выданы начальные средства, создан начальный блок в цепи
# Запуск модели сети.
# Модельное время:  0
# Клиент Client 1 прислал 46 денег клиенту Client 2
# Создана транзакция Transaction(sender=Client 1, recipient=Client 2, value=46, time=2021-10-13 16:44:37.854144)
# Идентификатор транзакции: 65547
#
# Модельное время:  5
# Клиент Client 9 прислал 25 денег клиенту Client 2
# Создана транзакция Transaction(sender=Client 9, recipient=Client 2, value=25, time=2021-10-13 16:44:39.785707)
# Идентификатор транзакции: 65548
#
# Модельное время:  6
# Клиент Client 8 прислал 19 денег клиенту Client 4
# Создана транзакция Transaction(sender=Client 8, recipient=Client 4, value=19, time=2021-10-13 16:44:41.630466)
# Идентификатор транзакции: 65549
#
# Майнер Miner11 обработает текущую цепочку транзакций
# Создан блок Block(id=2, previous_block_hash=I'm hash of the initial block, nonce=0e873d32d432ca4c6022be1c3488e52b)
# Модельное время:  7
# Клиент Client 6 прислал 32 денег клиенту Client 4
# Создана транзакция Transaction(sender=Client 6, recipient=Client 4, value=32, time=2021-10-13 16:44:42.725573)
# Идентификатор транзакции: 65550
#
# Модельное время:  9
# Клиент Client 1 прислал 37 денег клиенту Client 9
# Создана транзакция Transaction(sender=Client 1, recipient=Client 9, value=37, time=2021-10-13 16:44:44.560732)
# Идентификатор транзакции: 65551
#
# Модельное время:  11
# Клиент Client 9 прислал 26 денег клиенту Client 7
# Создана транзакция Transaction(sender=Client 9, recipient=Client 7, value=26, time=2021-10-13 16:44:46.279600)
# Идентификатор транзакции: 65552
#
# Майнер Miner12 обработает текущую цепочку транзакций
# Создан блок Block(id=3, previous_block_hash=0e873d32d432ca4c6022be1c3488e52b, nonce=0b660df1083dbf8439803de2dfab9f74)
# Модельное время:  12
# Клиент Client 3 прислал 38 денег клиенту Client 1
# Создана транзакция Transaction(sender=Client 3, recipient=Client 1, value=38, time=2021-10-13 16:44:47.451129)
# Идентификатор транзакции: 65553
#
# Модельное время:  14
# Клиент Client 9 прислал 18 денег клиенту Client 4
# Создана транзакция Transaction(sender=Client 9, recipient=Client 4, value=18, time=2021-10-13 16:44:49.334455)
# Идентификатор транзакции: 65554
#
# Модельное время:  15
# Клиент Client 5 прислал 23 денег клиенту Client 8
# Создана транзакция Transaction(sender=Client 5, recipient=Client 8, value=23, time=2021-10-13 16:44:50.364378)
# Идентификатор транзакции: 65555
#
# Майнер Miner11 обработает текущую цепочку транзакций
# Создан блок Block(id=4, previous_block_hash=0b660df1083dbf8439803de2dfab9f74, nonce=0facba329459ad35eac974cf3e77a760)
# Модельное время:  17
# Клиент Client 8 прислал 43 денег клиенту Client 4
# Создана транзакция Transaction(sender=Client 8, recipient=Client 4, value=43, time=2021-10-13 16:44:52.004865)
# Идентификатор транзакции: 65556
#
# Модельное время:  18
# Клиент Client 2 прислал 27 денег клиенту Client 7
# Создана транзакция Transaction(sender=Client 2, recipient=Client 7, value=27, time=2021-10-13 16:44:53.484913)
# Идентификатор транзакции: 65557
#
# Модельное время:  20
# Клиент Client 5 прислал 41 денег клиенту Client 7
# Создана транзакция Transaction(sender=Client 5, recipient=Client 7, value=41, time=2021-10-13 16:44:54.793774)
# Идентификатор транзакции: 65558
#
# Майнер Miner12 обработает текущую цепочку транзакций
# Создан блок Block(id=5, previous_block_hash=0facba329459ad35eac974cf3e77a760, nonce=07330c5fcfb458e49f86429c27839849)
# Модельное время:  21
# Клиент Client 1 прислал 12 денег клиенту Client 9
# Создана транзакция Transaction(sender=Client 1, recipient=Client 9, value=12, time=2021-10-13 16:44:56.073018)
# Идентификатор транзакции: 65559
#
# Модельное время:  22
# Клиент Client 7 прислал 36 денег клиенту Client 10
# Создана транзакция Transaction(sender=Client 7, recipient=Client 10, value=36, time=2021-10-13 16:44:57.458029)
# Идентификатор транзакции: 65560
#
# Модельное время:  24
# Клиент Client 4 прислал 33 денег клиенту Client 2
# Создана транзакция Transaction(sender=Client 4, recipient=Client 2, value=33, time=2021-10-13 16:44:59.206072)
# Идентификатор транзакции: 65561
#
# Майнер Miner12 обработает текущую цепочку транзакций
# Создан блок Block(id=6, previous_block_hash=07330c5fcfb458e49f86429c27839849, nonce=00078b2dff60c6b3823edd6c1166cb22)
# Модельное время:  26
# Клиент Client 1 прислал 22 денег клиенту Client 2
# Создана транзакция Transaction(sender=Client 1, recipient=Client 2, value=22, time=2021-10-13 16:45:00.878304)
# Идентификатор транзакции: 65562
#
# Модельное время:  27
# Клиент Client 5 прислал 49 денег клиенту Client 4
# Создана транзакция Transaction(sender=Client 5, recipient=Client 4, value=49, time=2021-10-13 16:45:02.265721)
# Идентификатор транзакции: 65563
#
# Модельное время:  28
# Клиент Client 10 прислал 17 денег клиенту Client 9
# Создана транзакция Transaction(sender=Client 10, recipient=Client 9, value=17, time=2021-10-13 16:45:03.296234)
# Идентификатор транзакции: 65564
#
# Майнер Miner11 обработает текущую цепочку транзакций
# Создан блок Block(id=7, previous_block_hash=00078b2dff60c6b3823edd6c1166cb22, nonce=0a1f790b52320fd446bf3ee41ec7ce8a)
# Модельное время:  30
# Клиент Client 3 прислал 31 денег клиенту Client 10
# Создана транзакция Transaction(sender=Client 3, recipient=Client 10, value=31, time=2021-10-13 16:45:05.253454)
# Идентификатор транзакции: 65565
#
# Модельное время:  31
# Клиент Client 7 прислал 26 денег клиенту Client 4
# Создана транзакция Transaction(sender=Client 7, recipient=Client 4, value=26, time=2021-10-13 16:45:06.357485)
# Идентификатор транзакции: 65566
#
# Модельное время:  33
# Клиент Client 7 прислал 35 денег клиенту Client 9
# Создана транзакция Transaction(sender=Client 7, recipient=Client 9, value=35, time=2021-10-13 16:45:08.338861)
# Идентификатор транзакции: 65567
#
# Майнер Miner11 обработает текущую цепочку транзакций
# Создан блок Block(id=8, previous_block_hash=0a1f790b52320fd446bf3ee41ec7ce8a, nonce=0c7cc7306a340632a4bf232c5cfb9121)
# Модельное время:  34
# Клиент Client 2 прислал 50 денег клиенту Client 8
# Создана транзакция Transaction(sender=Client 2, recipient=Client 8, value=50, time=2021-10-13 16:45:09.616476)
# Идентификатор транзакции: 65568
#
# Модельное время:  36
# Клиент Client 2 прислал 21 денег клиенту Client 5
# Создана транзакция Transaction(sender=Client 2, recipient=Client 5, value=21, time=2021-10-13 16:45:10.910987)
# Идентификатор транзакции: 65569
#
# Модельное время:  37
# Клиент Client 8 прислал 37 денег клиенту Client 3
# Создана транзакция Transaction(sender=Client 8, recipient=Client 3, value=37, time=2021-10-13 16:45:12.169173)
# Идентификатор транзакции: 65570
#
# Майнер Miner11 обработает текущую цепочку транзакций
# Создан блок Block(id=9, previous_block_hash=0c7cc7306a340632a4bf232c5cfb9121, nonce=0a4bfe7658226d37f4a194187a80b9ae)
# Модельное время:  39
# Клиент Client 6 прислал 20 денег клиенту Client 5
# Создана транзакция Transaction(sender=Client 6, recipient=Client 5, value=20, time=2021-10-13 16:45:14.126526)
# Идентификатор транзакции: 65571
#
# Модельное время:  40
# Клиент Client 2 прислал 31 денег клиенту Client 3
# Создана транзакция Transaction(sender=Client 2, recipient=Client 3, value=31, time=2021-10-13 16:45:15.247601)
# Идентификатор транзакции: 65572
#
# Модельное время:  41
# Клиент Client 7 прислал 12 денег клиенту Client 9
# Создана транзакция Transaction(sender=Client 7, recipient=Client 9, value=12, time=2021-10-13 16:45:16.751225)
# Идентификатор транзакции: 65573
#
# Майнер Miner11 обработает текущую цепочку транзакций
# Создан блок Block(id=10, previous_block_hash=0a4bfe7658226d37f4a194187a80b9ae, nonce=0c1d3d574c7978089883fa5d14f46627)
# Модельное время:  43
# Клиент Client 3 прислал 44 денег клиенту Client 9
# Создана транзакция Transaction(sender=Client 3, recipient=Client 9, value=44, time=2021-10-13 16:45:18.647524)
# Идентификатор транзакции: 65574
#
# Модельное время:  45
# Клиент Client 7 прислал 11 денег клиенту Client 4
# Создана транзакция Transaction(sender=Client 7, recipient=Client 4, value=11, time=2021-10-13 16:45:20.604385)
# Идентификатор транзакции: 65575
#
# Модельное время:  47
# Клиент Client 7 прислал 13 денег клиенту Client 10
# Создана транзакция Transaction(sender=Client 7, recipient=Client 10, value=13, time=2021-10-13 16:45:21.946806)
# Идентификатор транзакции: 65576
#
# Майнер Miner11 обработает текущую цепочку транзакций
# Создан блок Block(id=11, previous_block_hash=0c1d3d574c7978089883fa5d14f46627, nonce=0f3f052bace128d32113075afdd59d09)
# Модельное время:  48
# Клиент Client 9 прислал 13 денег клиенту Client 10
# Создана транзакция Transaction(sender=Client 9, recipient=Client 10, value=13, time=2021-10-13 16:45:23.715966)
# Идентификатор транзакции: 65577
#
# Модельное время:  50
# Клиент Client 3 прислал 30 денег клиенту Client 9
# Создана транзакция Transaction(sender=Client 3, recipient=Client 9, value=30, time=2021-10-13 16:45:25.505844)
# Идентификатор транзакции: 65578
#
# Модельное время:  51
# Клиент Client 7 прислал 42 денег клиенту Client 3
# Создана транзакция Transaction(sender=Client 7, recipient=Client 3, value=42, time=2021-10-13 16:45:26.740108)
# Идентификатор транзакции: 65579
#
# Майнер Miner11 обработает текущую цепочку транзакций
# Создан блок Block(id=12, previous_block_hash=0f3f052bace128d32113075afdd59d09, nonce=0828a8738c20b3e375e752fa2926d341)
# Модельное время:  53
# Клиент Client 3 прислал 25 денег клиенту Client 7
# Создана транзакция Transaction(sender=Client 3, recipient=Client 7, value=25, time=2021-10-13 16:45:28.067809)
# Идентификатор транзакции: 65580
#
# Модельное время:  55
# Клиент Client 7 прислал 44 денег клиенту Client 8
# Создана транзакция Transaction(sender=Client 7, recipient=Client 8, value=44, time=2021-10-13 16:45:29.889501)
# Идентификатор транзакции: 65581
#
# Модельное время:  56
# Клиент Client 6 прислал 50 денег клиенту Client 8
# Создана транзакция Transaction(sender=Client 6, recipient=Client 8, value=50, time=2021-10-13 16:45:31.240537)
# Идентификатор транзакции: 65582
#
# Майнер Miner11 обработает текущую цепочку транзакций
# Создан блок Block(id=13, previous_block_hash=0828a8738c20b3e375e752fa2926d341, nonce=0ec3c039e919c4d4138fe02bfaf75567)
# Модельное время:  57
# Клиент Client 6 прислал 50 денег клиенту Client 5
# Создана транзакция Transaction(sender=Client 6, recipient=Client 5, value=50, time=2021-10-13 16:45:32.630125)
# Идентификатор транзакции: 65583
#
# Модельное время:  59
# Клиент Client 2 прислал 45 денег клиенту Client 6
# Создана транзакция Transaction(sender=Client 2, recipient=Client 6, value=45, time=2021-10-13 16:45:34.402251)
# Идентификатор транзакции: 65584
#
# Блоков в цепи:	 13
# Необработанных транзакций:	 2
